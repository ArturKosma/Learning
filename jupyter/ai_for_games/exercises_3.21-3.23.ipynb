# %% [markdown]
# ### For the best experience, view this notebook on nbviewer:
# [Open in nbviewer](https://nbviewer.org/github/ArturKosma/Learning/blob/main/jupyter/ai_for_games/exercises_3.21-3.23.ipynb)

# %%
import leqanimlib
import leqmath
import numpy as np

# %% [markdown]
# ![image.png](attachment:c6f58ee2-7cad-4628-8ef6-c910eb5f489f.png)

# %% [markdown]
# ![image.png](attachment:3c9b7d55-eb98-4684-8146-b0d16eb75af7.png)

# %% [markdown]
# ![image.png](attachment:ac9b9fcb-720a-47fc-9e5a-9ca999c6a2ce.png)

# %% [markdown]
# ![image.png](attachment:dbb198e3-ae6e-4c7a-8ee1-881c7f2f248b.png)

# %% [markdown]
# ![image.png](attachment:3d626150-32e5-4337-9717-b2d76e503451.png)

# %% [markdown]
# ![image.png](attachment:d43cceee-1830-4807-982d-8adf96c9a5c0.png)

# %% [markdown]
# ![image.png](attachment:75bcf9cf-a1fe-412a-8940-33accb607802.png)

# %% [markdown]
# ![image.png](attachment:30993a06-3f6d-4bd6-ba96-120bc118c86b.png)

# %% [markdown]
# ![image.png](attachment:7016ae2e-de92-4eb6-af7b-c8d3973b1ec6.png)

# %% [markdown]
# 1. We normalize the axis.

# %%
axis = np.array([8/170, 15/17, 0], dtype=float)
axis /= np.linalg.norm(axis)
print(axis)
# Out:
# [0.05325764 0.9985808  0.        ]

# %% [markdown]
# 2. We find the cos and sin components of the quaternion.

# %%
theta = (2 * np.pi) / 3

cos = np.cos(theta / 2)
sin = np.sin(theta / 2)

# %% [markdown]
# 3. We find all 4 components of the quaternion.

# %%
quat = np.array([cos, axis[0] * sin, axis[1] * sin, axis[2] * sin], dtype=float)
print(quat)
# Out:
# [0.5        0.04612247 0.86479634 0.        ]

# %% [markdown]
# Confirmed with ChatGPT 4.0

# %% [markdown]
# ![image.png](attachment:3a7515e1-31bb-45b1-8282-c1da7129773a.png)

# %% [markdown]
# ![image.png](attachment:7cba8926-82a1-4004-9172-8f82438801e6.png)

# %% [markdown]
# I'm not sure what is p here. Anyway, I'm providing the algorithm for fake rotation.

# %% [markdown]
# ![image.png](attachment:5816ca70-f16d-4cd1-bad8-1b68dd2b047b.png)
